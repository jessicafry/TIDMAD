# %% [markdown]
# # Axion-photon coupling limits vs axion mass
#
# Axion mass-PQ scale relation:
# \begin{equation}
# m_{a}=5.70(7) \mu \mathrm{eV}\left(\frac{10^{12} \,\mathrm{GeV}}{f_{a}}\right)
# \end{equation}
#
# Axion-photon coupling
# \begin{equation}
# g_{a \gamma} \equiv \frac{\alpha}{2 \pi} \frac{C_{a\gamma}}{f_{a}}=2.0 \times 10^{-16} C_{a \gamma} \frac{m_{a}}{\mu \mathrm{eV}} \mathrm{GeV}^{-1}
# \end{equation}
#
# Model dependent constant:
# \begin{equation}
# C_{a\gamma} \equiv \frac{E}{N} - 1.92(4) =
# \begin{cases}
#   -1.92, & {\rm KSVZ} \\
#   0.75, & {\rm DFSZ\,I} \\
#   -1.25, & {\rm DFSZ\,II}
# \end{cases}
# \end{equation}

# %%
# %matplotlib inline
from numpy import *
import matplotlib.pyplot as plt
from PlotFuncs_TIDMAD import FigSetup, AxionPhoton, MySaveFig, BlackHoleSpins, FilledLimit, line_background

import os 
os.environ["PATH"] += os.pathsep + '/Library/TeX/texbin'

fig,ax = FigSetup(Shape='Rectangular',ylab=r'$|g_{a\gamma\gamma}|$ [GeV$^{-1}$]',mathpazo=True)

# Shaft
col = [120/255, 120/255, 120/255]
AxionPhoton.SHAFT_TIDMAD(ax,col=col,edgealpha=1,alpha=1)

# Astrophysics
col = [240/255, 240/255, 240/255]
AxionPhoton.LowMassAstroBounds_TIDMAD(ax,col=col)

# QCD Axion
AxionPhoton.QCDAxion_TIDMAD(ax)

# ABRA
AxionPhoton.ABRACADABRA_TIDMAD("brazilBand_largedata_coarse.csv","brazil_all_FCNet_0_4.csv",ax,col='red',edgealpha=0)
AxionPhoton.ABRACADABRA_original(ax,col='pink',text_shift=[3,0.18])


# Haloscopes
# AxionPhoton.HaloscopesUniform(ax)
col = [220/255, 220/255, 220/255]
AxionPhoton.HaloscopesUniform_TIDMAD(ax,text_on=False,col=col)#col='blue')

# # Telescope
# col='royalblue'
# text_on = False
# AxionPhoton.MUSE(ax,text_on=text_on,col=col)
# AxionPhoton.VIMOS(ax,text_on=text_on,col=col)
# # AxionPhoton.HST(ax,text_on=text_on,col=col)
# fs=18
# text_pos=[2,1e-11]
# rotation=0
# ax.text(text_pos[0],text_pos[1],r'{\bf Telescope}',fontsize=fs,color='w',rotation=rotation,ha='center',va='top',clip_on=True,path_effects=line_background(1.5,'k'))

# # Stars
# # AxionPhoton.AxionStarExplosions(ax)
# # AxionPhoton.NeutronStars(ax)
# AxionPhoton.StellarBounds_Mo(ax)

# CAST
col = [200/255, 200/255, 200/255]
AxionPhoton.Helioscopes(ax,text_on=False,col=col)#col='orange')
fs=18
text_pos=[1e-4,1.5e-9]
rotation=0
ax.text(text_pos[0],text_pos[1],r'{\bf CAST}',fontsize=fs,color='w',rotation=rotation,ha='center',va='top',clip_on=True,path_effects=line_background(1.5,'k'))


# Light-shining-through-walls
col = [160/255, 160/255, 160/255]
AxionPhoton.LSW_TIDMAD(ax, col=col)

#BlackHoleSpins(ax,(1/137)*(1/(2*pi)),[1.5e-12,0.5e-17],rotation=-90,alpha=1,fs=18,facecolor=[0.7,0.7,0.7],whichfile='Baryakhtar')

plt.xlim(1e-11, 1e-3)
MySaveFig(fig,'AxionPhoton')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File /opt/homebrew/lib/python3.11/site-packages/matplotlib/texmanager.py:250, in TexManager._run_checked_subprocess(cls, command, tex, cwd)
#     249 try:
# --> 250     report = subprocess.check_output(
#     251         command, cwd=cwd if cwd is not None else cls._texcache,
#     252         stderr=subprocess.STDOUT)
#     253 except FileNotFoundError as exc:
#
# File /opt/homebrew/Cellar/python@3.11/3.11.6_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/subprocess.py:466, in check_output(timeout, *popenargs, **kwargs)
#     464     kwargs['input'] = empty
# --> 466 return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     467            **kwargs).stdout
#
# ...

# %%
# !pip install latex
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.3/491.3 kB 11.0 MB/s eta 0:00:00a 0:00:01
# ...
#   Created wheel for latex: filename=latex-0.7.0-py3-none-any.whl size=7589 sha256=bd11504351453574109f3b9964258b4c6e2617030aa2fbf7525472befb488c24
#   Stored in directory: /Users/liaobo77/Library/Caches/pip/wheels/e5/b3/95/f4b45b5116d4585893cdcb2ac7c07614a59fb047c754c4651a
# ...
#   Created wheel for data: filename=data-0.4-py3-none-any.whl size=7227 sha256=197ebe8d51137e9260732076b355ab4c49bc9b7e7c74764f37178c193621a3ff
#   Stored in directory: /Users/liaobo77/Library/Caches/pip/wheels/d2/d3/10/d5fe9bc9dcb197ea289baccca92a25f2f95135235a92ca1b11
# ...
#   Created wheel for shutilwhich: filename=shutilwhich-1.1.0-py3-none-any.whl size=2766 sha256=83d7d8c4dc1015fc3acceaccb80a680959b88229a5d3de63ed3b492d4258507f
# ...

# %%
# !brew install latex
# Out:
# ...
# ==> Searching for similarly named formulae and casks...
# ==> Formulae
# arxiv_latex_cleaner        latex2rtf                  latexml
# gnome-latex                latexdiff                  rtf2latex2e
# latex2html                 latexindent
#
# To install arxiv_latex_cleaner, run:
#   brew install arxiv_latex_cleaner
#
# ==> Casks
# atext           klatexformula   latest          latexdraw       latexit
#
# To install atext, run:
#   brew install --cask atext
